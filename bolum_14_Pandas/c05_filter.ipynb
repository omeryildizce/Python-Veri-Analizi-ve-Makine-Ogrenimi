# %%
import pandas as pd

# %%
films = pd.read_csv("../veri_seti/imdb_1000.csv")
films
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
films.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
films["title"].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
films.title.head(5)
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
films[["title", "star_rating"]].head()
# Out:
#                       title  star_rating
# 0  The Shawshank Redemption          9.3
# 1             The Godfather          9.2
# 2    The Godfather: Part II          9.1
# 3           The Dark Knight          9.0
# 4              Pulp Fiction          8.9

# %%
films[:9][["title", "star_rating"]]
# Out:
#                                            title  star_rating
# 0                       The Shawshank Redemption          9.3
# 1                                  The Godfather          9.2
# 2                         The Godfather: Part II          9.1
# 3                                The Dark Knight          9.0
# 4                                   Pulp Fiction          8.9
# 5                                   12 Angry Men          8.9
# 6                 The Good, the Bad and the Ugly          8.9
# 7  The Lord of the Rings: The Return of the King          8.9
# 8                               Schindler's List          8.9

# %%
films[(films["star_rating"] > 8.5)][["title", "star_rating"]]
# Out:
#                                                 title  star_rating
# 0                            The Shawshank Redemption          9.3
# 1                                       The Godfather          9.2
# 2                              The Godfather: Part II          9.1
# 3                                     The Dark Knight          9.0
# 4                                        Pulp Fiction          8.9
# 5                                        12 Angry Men          8.9
# 6                      The Good, the Bad and the Ugly          8.9
# 7       The Lord of the Rings: The Return of the King          8.9
# 8                                    Schindler's List          8.9
# 9                                          Fight Club          8.9
# 10  The Lord of the Rings: The Fellowship of the Ring          8.8
# 11                                          Inception          8.8
# 12     Star Wars: Episode V - The Empire Strikes Back          8.8
# ...

# %%
films[(films["star_rating"] > 8.5)  &(
    films["star_rating"] < 9)][["title", "star_rating"]]
# Out:
#                                                 title  star_rating
# 4                                        Pulp Fiction          8.9
# 5                                        12 Angry Men          8.9
# 6                      The Good, the Bad and the Ugly          8.9
# 7       The Lord of the Rings: The Return of the King          8.9
# 8                                    Schindler's List          8.9
# 9                                          Fight Club          8.9
# 10  The Lord of the Rings: The Fellowship of the Ring          8.8
# 11                                          Inception          8.8
# 12     Star Wars: Episode V - The Empire Strikes Back          8.8
# 13                                       Forrest Gump          8.8
# 14              The Lord of the Rings: The Two Towers          8.8
# 15                                       Interstellar          8.7
# 16                    One Flew Over the Cuckoo's Nest          8.7
# ...

# %%
films.query("star_rating >= 9.0 | star_rating == 8.5")[["title","star_rating"]]
# Out:
#                                                 title  star_rating
# 0                            The Shawshank Redemption          9.3
# 1                                       The Godfather          9.2
# 2                              The Godfather: Part II          9.1
# 3                                     The Dark Knight          9.0
# 40                                     The Green Mile          8.5
# 41                                       Sunset Blvd.          8.5
# 42                                        The Pianist          8.5
# 43                              The Dark Knight Rises          8.5
# 44                                          Gladiator          8.5
# 45                         Terminator 2: Judgment Day          8.5
# 46                                            Memento          8.5
# 47                                   Taare Zameen Par          8.5
# 48  Dr. Strangelove or: How I Learned to Stop Worr...          8.5
# ...
